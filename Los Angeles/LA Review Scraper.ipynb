# %%
import csv
import time
import requests
import pandas as pd
from time import sleep
from bs4 import BeautifulSoup
from nordvpn_switcher import initialize_VPN, rotate_VPN, terminate_VPN

all_restaurants_url = pd.read_csv('losangeles.csv', header=None)[0].values
initialize_VPN(save=1,area_input=['complete rotation']) 
user_agent = {'User-agent': 'Mozilla/5.0'}

reviewText = []
reviewRating = []
reviewDate = []
reviewRestaurantName = []

for base_url in all_restaurants_url[:2]:
    counter = 0
    url = base_url +'&sort_by=date_asc'

    while counter < 20:
        try:    
            restaurantPage = requests.get(url)
        except:
            break

        restaurantPageSoup = BeautifulSoup(
            restaurantPage.text, "html.parser"
        )
        reviewsRawList = restaurantPageSoup.findAll(
            "li",
            class_="margin-b5__09f24__pTvws border-color--default__09f24__NPAKY",
        )

        SoupRestaurantName = restaurantPageSoup.find('h1').getText()

        for review in reviewsRawList:
            try:
                reviewText.append(review.find('span', class_="raw__09f24__T4Ezm").getText())
                reviewRating.append(int(review.find("div", class_="five-stars__09f24__mBKym five-stars--regular__09f24__DgBNj display--inline-block__09f24__fEDiJ border-color--default__09f24__NPAKY")['aria-label'][0]))
                reviewDate.append(review.find("span", {"class": "css-chan6m"}).getText())
                reviewRestaurantName.append(SoupRestaurantName)
            except:
                pass

        sleep(1)     

        counter += 1
        url = base_url + '&start=' + str(counter*10) + '&sort_by=date_asc' 
        
        d = {'Review': reviewText, 'Rating': reviewRating, 'Date' : reviewDate, 'Restaurant Name': reviewRestaurantName}
        df = pd.DataFrame(data=d)
        df.to_csv('la0_5.csv') #Give different name per city
        
    #execute this code when counter >= 20
    rotate_VPN()
    time.sleep(2)  
    print("VPN has been switched")
# Out:
# You're using Windows.
# Performing system check...
# ###########################
#
# NordVPN installation check: ✓
# NordVPN service check: ✓
# Opening NordVPN app and disconnecting if necessary...
# NordVPN app launched: ✓
# #####################################
#
# You've entered a list of connection options. Checking list...
#
#
# Fetching list of all current NordVPN servers...
#
#
# Saving settings in project folder...
#
#
# Done!
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [52], in <cell line: 18>()
#      28 restaurantPageSoup = BeautifulSoup(
#      29     restaurantPage.text, "html.parser"
#      30 )
#      31 reviewsRawList = restaurantPageSoup.findAll(
#      32     "li",
#      33     class_="margin-b5__09f24__pTvws border-color--default__09f24__NPAKY",
#      34 )
# ---> 36 SoupRestaurantName = restaurantPageSoup.find('h1').getText()
#      38 for review in reviewsRawList:
#      39     try:
#
# AttributeError: 'NoneType' object has no attribute 'getText'

# %%
import numpy as np
d = {'Review': reviewText, 'Rating': reviewRating, 'Date' : reviewDate, 'Restaurant Name': reviewRestaurantName}
df = pd.DataFrame(data=d)
df
# Out:
#                                                  Review  Rating        Date  \
# 0     Awesome!!! Great food and great serviceI  will...       5  10/25/2015
# 1     If food is running out before their closure ti...       1  10/27/2015
# 2     I was trying to make a Togo order through the ...       1  10/27/2015
# 3     ***long story short, I called for a pick up or...       1  10/28/2015
# 4     Apparently its their soft opening period and t...       5  10/29/2015
# ...                                                 ...     ...         ...
# 9495  First time here and felt very welcome!! Person...       5   1/14/2017
# 9496  The service was the absolute best, the busines...       3   1/15/2017
# 9497  Great food and great service. All their dishes...       5   1/16/2017
# 9498  Carne asada fries are probably the best I have...       5   1/18/2017
# 9499  Friendly service. Delicious food  got the shwa...       5   1/20/2017
#
#      Restaurant Name
# 0        Yup Dduk LA
# 1        Yup Dduk LA
# 2        Yup Dduk LA
# 3        Yup Dduk LA
# 4        Yup Dduk LA
# ...              ...
# 9495  Fatima's Grill
# 9496  Fatima's Grill
# 9497  Fatima's Grill
# 9498  Fatima's Grill
# 9499  Fatima's Grill
#
# [9500 rows x 4 columns]
