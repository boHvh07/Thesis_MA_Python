# %%
import csv
import time
import requests
import pandas as pd
from time import sleep
from bs4 import BeautifulSoup
from nordvpn_switcher import initialize_VPN, rotate_VPN, terminate_VPN

all_restaurants_url = pd.read_csv('houston.csv', header=None)[0].values
initialize_VPN(save=1,area_input=['complete rotation']) 
user_agent = {'User-agent': 'Mozilla/5.0'}

reviewText = []
reviewRating = []
reviewDate = []
reviewRestaurantName = []

for base_url in all_restaurants_url:
    counter = 0
    url = base_url +'&sort_by=date_asc'

    while counter < 20:
        try:    
            restaurantPage = requests.get(url)
        except:
            break

        restaurantPageSoup = BeautifulSoup(
            restaurantPage.text, "html.parser"
        )
        reviewsRawList = restaurantPageSoup.findAll(
            "li",
            class_="margin-b5__09f24__pTvws border-color--default__09f24__NPAKY",
        )

        SoupRestaurantName = restaurantPageSoup.find('h1').getText()

        for review in reviewsRawList:
            try:
                reviewText.append(review.find('span', class_="raw__09f24__T4Ezm").getText())
                reviewRating.append(int(review.find("div", class_="five-stars__09f24__mBKym five-stars--regular__09f24__DgBNj display--inline-block__09f24__fEDiJ border-color--default__09f24__NPAKY")['aria-label'][0]))
                reviewDate.append(review.find("span", {"class": "css-chan6m"}).getText())
                reviewRestaurantName.append(SoupRestaurantName)
            except:
                pass

        sleep(1)     

        counter += 1
        url = base_url + '&start=' + str(counter*10) + '&sort_by=date_asc' 
        
        d = {'Review': reviewText, 'Rating': reviewRating, 'Date' : reviewDate, 'Restaurant Name': reviewRestaurantName}
        df = pd.DataFrame(data=d)
        df.to_csv('houston10.csv') #Give different name per city
        
    #execute this code when counter >= 20
    rotate_VPN()
    time.sleep(3)  
    print("VPN has been switched")
# Out:
# You're using Windows.
# Performing system check...
# ###########################
#
# NordVPN installation check: ✓
# NordVPN service check: ✓
# Opening NordVPN app and disconnecting if necessary...
# NordVPN app launched: ✓
# #####################################
#
# You've entered a list of connection options. Checking list...
#
#
# Fetching list of all current NordVPN servers...
#
#
# Saving settings in project folder...
#
#
# Done!
#
# Trying to load saved settings...
# Saved settings loaded!
#
#
# Your current ip-address is: 137.56.58.91
#
# Connecting you to Netherlands #864 ...
#
# your new ip-address is: 193.29.60.238
#
# Done! Enjoy your new server.
#
# VPN has been switched
# Trying to load saved settings...
# Saved settings loaded!
#
#
# Your current ip-address is: 193.29.60.238
#
# Connecting you to Switzerland #334 ...
#
# your new ip-address is: 178.239.165.38
#
# Done! Enjoy your new server.
#
# VPN has been switched
# Trying to load saved settings...
# Saved settings loaded!
#
#
# Your current ip-address is: 178.239.165.38
#
# Connecting you to Germany #1044 ...
#
# your new ip-address is: 185.196.22.197
#
# Done! Enjoy your new server.
#
# VPN has been switched
# Trying to load saved settings...
# Saved settings loaded!
#
#
# Your current ip-address is: 185.196.22.197
#
# Connecting you to Mexico #80 ...
#
# your new ip-address is: 185.153.177.133
#
# Done! Enjoy your new server.
#
# VPN has been switched
# Trying to load saved settings...
# Saved settings loaded!
#
#
# Your current ip-address is: 185.153.177.133
#
# Connecting you to United Kingdom #2092 ...
#
# your new ip-address is: 185.169.233.220
#
# Done! Enjoy your new server.
#
# VPN has been switched
# Trying to load saved settings...
# Saved settings loaded!
#
#
# Your current ip-address is: 185.169.233.220
#
# Connecting you to Canada #1675 ...
#
# your new ip-address is: 185.212.118.230
#
# Done! Enjoy your new server.
#
# VPN has been switched
# Trying to load saved settings...
# Saved settings loaded!
#
#
# Your current ip-address is: 185.212.118.230
#
# Connecting you to Canada #1573 ...
#
# your new ip-address is: 185.153.179.42
#
# Done! Enjoy your new server.
#
# VPN has been switched
# Trying to load saved settings...
# Saved settings loaded!
#
#
# Your current ip-address is: 185.153.179.42
#
# Connecting you to United States #9319 ...
#
# your new ip-address is: 193.42.0.55
#
# Done! Enjoy your new server.
#
# VPN has been switched
# Trying to load saved settings...
# Saved settings loaded!
#
#
# Your current ip-address is: 193.42.0.55
#
# Connecting you to United States #9591 ...
#
# your new ip-address is: 195.206.104.188
#
# Done! Enjoy your new server.
#
# VPN has been switched
# Trying to load saved settings...
# Saved settings loaded!
#
#
# Your current ip-address is: 195.206.104.188
#
# Connecting you to Netherlands #731 ...
#
# your new ip-address is: 193.29.60.6
#
# Done! Enjoy your new server.
#
# VPN has been switched
# Trying to load saved settings...
# Saved settings loaded!
#
#
# Your current ip-address is: 193.29.60.6
#
# Connecting you to United Kingdom #1815 ...
#
# your new ip-address is: 178.238.11.65
#
# Done! Enjoy your new server.
#
# VPN has been switched
# Trying to load saved settings...
# Saved settings loaded!
#
#
# Your current ip-address is: 178.238.11.65
#
# Connecting you to United States #9146 ...
#
# your new ip-address is: 2.56.190.5
#
# Done! Enjoy your new server.
#
# VPN has been switched
# Trying to load saved settings...
# Saved settings loaded!
#
#
# Your current ip-address is: 2.56.190.5
#
# Connecting you to Netherlands #717 ...
#
# your new ip-address is: 82.180.149.117
#
# Done! Enjoy your new server.
#
# VPN has been switched
# Trying to load saved settings...
# Saved settings loaded!
#
#
# Your current ip-address is: 82.180.149.117
#
# Connecting you to Poland #143 ...
#
# your new ip-address is: 185.219.143.218
#
# Done! Enjoy your new server.
#
# VPN has been switched
# Trying to load saved settings...
# Saved settings loaded!
#
#
# Your current ip-address is: 185.219.143.218
#
# Connecting you to United States #9296 ...
#
# your new ip-address is: 185.203.219.14
#
# Done! Enjoy your new server.
#
# VPN has been switched
# Trying to load saved settings...
# Saved settings loaded!
#
#
# Your current ip-address is: 185.203.219.14
#
# Connecting you to Switzerland #383 ...
#
# your new ip-address is: 89.37.173.230
#
# Done! Enjoy your new server.
#
# VPN has been switched
# Trying to load saved settings...
# Saved settings loaded!
#
#
# Your current ip-address is: 89.37.173.230
#
# Connecting you to Norway #179 ...
#
# your new ip-address is: 82.180.145.245
#
# Done! Enjoy your new server.
#
# VPN has been switched
# Trying to load saved settings...
# Saved settings loaded!
#
#
# Your current ip-address is: 82.180.145.245
#
# Connecting you to Hungary #55 ...
#
# your new ip-address is: 155.133.78.80
#
# Done! Enjoy your new server.
#
# VPN has been switched
# Trying to load saved settings...
# Saved settings loaded!
#
#
# Your current ip-address is: 155.133.78.80
#
# Connecting you to Greece #43 ...
#
# your new ip-address is: 194.150.167.149
#
# Done! Enjoy your new server.
#
# VPN has been switched
# Trying to load saved settings...
# Saved settings loaded!
#
#
# Your current ip-address is: 194.150.167.149
#
# Connecting you to United States #8640 ...
#
# your new ip-address is: 192.145.36.238
#
# Done! Enjoy your new server.
#
# VPN has been switched
# Trying to load saved settings...
# Saved settings loaded!
#
#
# Your current ip-address is: 192.145.36.238
#
# Connecting you to United States #9673 ...
#
# your new ip-address is: 185.187.168.135
#
# Done! Enjoy your new server.
#
# VPN has been switched
# Trying to load saved settings...
# Saved settings loaded!
#
#
# Your current ip-address is: 185.187.168.135
#
# Connecting you to Canada #1575 ...
#
# your new ip-address is: 176.100.43.200
#
# Done! Enjoy your new server.
#
# VPN has been switched
# Trying to load saved settings...
# Saved settings loaded!
#
#
# Your current ip-address is: 176.100.43.200
#
# Connecting you to United States #8537 ...
#
# your new ip-address is: 192.145.118.34
#
# Done! Enjoy your new server.
#
# VPN has been switched
# Trying to load saved settings...
# Saved settings loaded!
#
#
# Your current ip-address is: 192.145.118.34
#
# Connecting you to Chile #29 ...
#
# your new ip-address is: 82.180.149.214
#
# Done! Enjoy your new server.
#
# VPN has been switched
# Trying to load saved settings...
# Saved settings loaded!
#
#
# Your current ip-address is: 82.180.149.214
#
# Connecting you to United Kingdom #2100 ...
#
# your new ip-address is: 185.59.221.117
#
# Done! Enjoy your new server.
#
# VPN has been switched
# Trying to load saved settings...
# Saved settings loaded!
#
#
# Your current ip-address is: 185.59.221.117
#
# Connecting you to United Kingdom #2366 ...
#
# your new ip-address is: 5.101.168.141
#
# Done! Enjoy your new server.
#
# VPN has been switched
# Trying to load saved settings...
# Saved settings loaded!
#
#
# Your current ip-address is: 5.101.168.141
#
# Connecting you to Australia #684 ...
#
# your new ip-address is: 103.137.12.52
#
# Done! Enjoy your new server.
#
# VPN has been switched
# Trying to load saved settings...
# Saved settings loaded!
#
#
# Your current ip-address is: 103.137.12.52
#
# Connecting you to Switzerland #373 ...
#
# your new ip-address is: 45.8.149.252
#
# Done! Enjoy your new server.
#
# VPN has been switched
# Trying to load saved settings...
# Saved settings loaded!
#
#
# Your current ip-address is: 45.8.149.252
#
# Connecting you to United States #8246 ...
#
# your new ip-address is: 94.140.8.152
#
# Done! Enjoy your new server.
#
# VPN has been switched
# Trying to load saved settings...
# Saved settings loaded!
#
#
# Your current ip-address is: 94.140.8.152
#
# Connecting you to France #869 ...
#
# your new ip-address is: 146.70.105.204
#
# Done! Enjoy your new server.
# VPN has been switched
# Trying to load saved settings...
# Saved settings loaded!
#
#
# Your current ip-address is: 146.70.105.204
#
# Connecting you to United States #8626 ...
#
# your new ip-address is: 192.145.36.104
#
# Done! Enjoy your new server.
#
# VPN has been switched
# Trying to load saved settings...
# Saved settings loaded!
#
#
# Your current ip-address is: 192.145.36.104
#
# Connecting you to Moldova #20 ...
#
# your new ip-address is: 178.175.141.228
#
# Done! Enjoy your new server.
#
# VPN has been switched
# Trying to load saved settings...
# Saved settings loaded!
#
#
# Your current ip-address is: 178.175.141.228
#
# Connecting you to United Kingdom #2287 ...
#
# your new ip-address is: 89.38.69.160
#
# Done! Enjoy your new server.
#
# VPN has been switched
# Trying to load saved settings...
# Saved settings loaded!
#
#
# Your current ip-address is: 89.38.69.160
#
# Connecting you to United States #8700 ...
#
# your new ip-address is: 192.145.119.105
#
# Done! Enjoy your new server.
#
# VPN has been switched
# Trying to load saved settings...
# Saved settings loaded!
#
#
# Your current ip-address is: 192.145.119.105
#
# Connecting you to Bulgaria #63 ...
#
# your new ip-address is: 156.146.55.105
#
# Done! Enjoy your new server.
#
# VPN has been switched

# %%
import numpy as np
d = {'Review': reviewText, 'Rating': reviewRating, 'Date' : reviewDate, 'Restaurant Name': reviewRestaurantName}
df = pd.DataFrame(data=d)
df
# Out:
#                                                  Review  Rating       Date  \
# 0     Was excited about this bar opening and is nice...       1   2/9/2014
# 1     Was excited to check out this new spot. The up...       1  2/16/2014
# 2     I came into Prospect Park with some friends on...       4  2/23/2014
# 3     Came to try the wings and crawfish. Wayy bette...       5  2/24/2014
# 4     So I've gone to Prospect Park on two different...       1  2/25/2014
# ...                                                 ...     ...        ...
# 6995  I come here every week for lunch. Their dishes...       5   8/8/2017
# 6996  After traveling to Bangkok last December it ha...       5  8/12/2017
# 6997  The yellow curry and red curry were excellent....       4  8/21/2017
# 6998  I decided that last time we came in was just a...       5  8/22/2017
# 6999  This place has my heart when it comes to the K...       5  8/24/2017
#
#                 Restaurant Name
# 0                 Prospect Park
# 1                 Prospect Park
# 2                 Prospect Park
# 3                 Prospect Park
# 4                 Prospect Park
# ...                         ...
# 6995  Asia Market Thai Lao Food
# 6996  Asia Market Thai Lao Food
# 6997  Asia Market Thai Lao Food
# 6998  Asia Market Thai Lao Food
# 6999  Asia Market Thai Lao Food
#
# [7000 rows x 4 columns]
